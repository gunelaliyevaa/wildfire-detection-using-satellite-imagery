# %% [markdown]
# <a href="https://colab.research.google.com/github/gunelaliyevaa/wildfire-detection-using-satellite-imagery/blob/main/scripts/read_image_pil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read Images with PIL

# %%
from PIL import Image
from numpy.core.defchararray import index

# Read image from file and store in object of Image class.
# When you need to interact with original files on your disk, you can use the built-in open() function
image = Image.open("data/fire_satellite.webp")

# %%
print(image.format, image.size, image.mode)

# %%
image.show()  # Not efficient because it downloads the image first then shows

# %% [markdown]
# ByteIO act like virtual files, but instead of storing data on an OS disk, it stores data in memory as bytes.
# When you want to manipulate data in memory without creating temporary files, use BytesIO.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import io
import numpy as np

with open("data/fire_satellite.webp", "rb") as f:
    binary_image = f.read()

image = Image.open(io.BytesIO(binary_image))

image
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1136x852>

# %%
import os
from PIL import Image
import numpy as np


image_directory = r"../wildfire-test-ml/data"
image_files = [f for f in os.listdir(image_directory)]

images =[]

for image_file in image_files:
    image_path = os.path.join(image_directory, image_file)
    image = Image.open(image_path)

    images.append(image)

images[1]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=350x350>
